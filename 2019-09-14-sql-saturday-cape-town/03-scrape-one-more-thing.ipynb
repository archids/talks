# %% [markdown]
# <img src="https://www.exegetic.biz/img/exegetic-banner-black.svg" width="35%" align="right">
#
# # Web Scraping: One More Thing
#
# Andrew B. Collier (@datawookie | andrew@exegetic.biz)<br>
# Data Scientist / Founder<br>
# [Exegetic Analytics](https://www.exegetic.biz)

# %% [markdown]
# <span style="color: #3498db;">**↯ Notebooks**</span> available from https://bit.ly/2kxOTT9.

# %% [markdown]
# ![](fig/banner-suits.png)
#
# <br><br>
#
# <div style="text-align: right; font-size: 5rem; padding-bottom: 1rem;">
# <span style="color: #3498db;">Suits</span> is <span style="color: #3498db;">sexy</span> but <span style="color: #3498db;">local</span> is <span style="color: #3498db;">lekker</span>!
# </div>

# %% [markdown]
# Let's see if we can scrape some data from a local law firm. All of the data are on a single page so, in principle, this should be an easy scrape!

# %% [markdown]
# ## Setup
#
# Load some libraries.

# %%
from requests import get
from bs4 import BeautifulSoup

# %% [markdown]
# The URL. Open [this link](https://www.bowmanslaw.com/our-people/) in your browser.
#
# The first hint that something is different is the distinct delay in page load. What's happening there?

# %%
URL = "https://www.bowmanslaw.com/our-people/"

# %% [markdown]
# ## Scraping
#
# The first step will be to grab the HTML for the page.

# %%
response = get(URL, stream=True)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-ZA" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js">\n    <head>\n        <meta charset="UTF-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <link rel="profile" href="http://gmpg.org/xfn/11">\n                <link rel="icon" type="image/ico" href="https://www.bowmanslaw.com/wp-content/uploads/2016/07/favicon.ico">\n                <title>Our People - Bowmans</title>\n\n<!-- This site is optimized with the Yoast SEO Premium plugin v11.6 - https://yoast.com/wordpress/plugins/seo/ -->\n<link rel="canonical" href="https://www.bowmanslaw.com/our-people/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Our People - Bowmans" />\n<meta property="og:url" content="https://www.bowmanslaw.com/our-people/" />\n<meta 
# ...

# %% [markdown]
# This looks good. Let's turn that into a `BeautifulSoup` and scrape it!

# %%
html = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# Now we need to get a selector. We'll start by targeting the lawyers' names. Using the browser you'll find that the required selector is `.media-heading`.

# %%
html.select(".media-heading")
# Out:
# []

# %% [markdown]
# No results? What's happening here?
#
# Here's the problem: the content on this page is being generated by JavaScript. So it's happening on the client (the browsers) not the server. So the *static* web scraping tools that we've been looking at will no longer work.
#
# There's a different set of tools for scraping *dynamic* web sites. But that's another story for another day.
